# %% [markdown]
# ### 1번문제

# %%
# 값이 없어 발생하는 노란밑줄방지용
maxWeight = None
rowCount = None
weight = None
money = None
#-------------------------
def knapsack():
    array = [[0 for _ in range(maxWeight+1)] for _ in range(rowCount+1)]
    for row in range(1, rowCount+1):    # 1번 정답칸 : 0번 인덱스가 아닌 1번부터 rowCount 까지
        for col in range(1, maxWeight+1):
            if weight[row] > col:       # 2번 정답칸 : 배낭에 집어넣을수 없다면
                array[row][col] = array[row-1][col]
            else:
                value1 = money[row]+ array[row-1][col-weight[row]]
                value2 = array[row-1][col]
                array = [row][col] = max(value1, value2)

    return array[rowCount][maxWeight]

# %% [markdown]
# ### 2번 문제

# %%
# 전역변수 선언
SIZE = 5
queue = [None for _ in range(SIZE)]
front = rear = -1

# 함수 선언

def isQueueFull():
    global SIZE, queue, front, rear
    if(rear == SIZE-1):
        return True
    else:
        return False
    
def isQueueEmpty():
    global SIZE, queue, front, rear
    if(front == rear):
        return True
    else:
        return False
    
def enQueue(data):
    global SIZE, queue, front, rear
    if(isQueueFull()):
        print('큐가 꽉 찼습니다.')
        return
    rear += 1
    queue[rear] = data

def deQueue():
    global SIZE, queue, front, rear
    if(isQueueEmpty()):
        print('큐가 비었습니다.')
        return None
    front += 1
    data = queue[front]
    queue[front] = None
    i = 1

    # 기존 동작
    # for i in range(front+1, rear+1):
    #     queue[i-1] = queue[i]
    #     queue[i] = None
    # front = -1
    # rear -= 1

    # return data


    # while True 사용
    while True:
        if front == rear:
            break
        elif i == len(queue):
            break
        else:
            queue[i-1] = queue[i]
            queue[i] = None
            i += 1
    front = -1
    rear -= 1

    return data

def peek():
    global SIZE, queue, front, rear
    if(isQueueEmpty()):
        print('큐가 비었습니다.')
        return None
    return queue[front+1]

def nextPerson():
    str_menu = (f'손님을 들이려면 아무키나 입력하세요.\n'
                '종료하시려면 X키를 눌러주세요')
    print(str_menu)
    sel_menu = input('손님들이기 or 종료(X)').upper()
    return sel_menu


# 메인코드
if __name__ == '__main__':
    enQueue('정국')
    enQueue('뷔')
    enQueue('지민')
    enQueue('진')
    enQueue('슈가')
    print(f'대기 줄 상태 : {queue}')

    while True:
        sel_menu = nextPerson()
        if sel_menu == 'X':
            print('식당 영업 종료!')                # 중간에 종료가능
            break
        else:
            print(f'{deQueue()} 님 식당에 들어감')
            print(f'대기 줄 상태 : {queue}')        
            if queue[front+1] == None:              # 손님이 다 들이면 자동종료
                break
    print('식당 영업 종료!')
        
    
    
    
    # for _ in range(rear+1):
    #     print(f'{deQueue()} 님 식당에 들어감')
    #     print(f'대기 줄 상태 : {queue}')
    
    # print('식당 영업 종료!')
# Out:
# 대기 줄 상태 : ['정국', '뷔', '지민', '진', '슈가']
# 손님을 들이려면 아무키나 입력하세요.
# 종료하시려면 X키를 눌러주세요
# 정국 님 식당에 들어감
# 대기 줄 상태 : ['뷔', '지민', '진', '슈가', None]
# 손님을 들이려면 아무키나 입력하세요.
# 종료하시려면 X키를 눌러주세요
# 뷔 님 식당에 들어감
# 대기 줄 상태 : ['지민', '진', '슈가', None, None]
# 손님을 들이려면 아무키나 입력하세요.
# 종료하시려면 X키를 눌러주세요
# 지민 님 식당에 들어감
# 대기 줄 상태 : ['진', '슈가', None, None, None]
# 손님을 들이려면 아무키나 입력하세요.
# 종료하시려면 X키를 눌러주세요
# 진 님 식당에 들어감
# 대기 줄 상태 : ['슈가', None, None, None, None]
# 손님을 들이려면 아무키나 입력하세요.
# 종료하시려면 X키를 눌러주세요
# 슈가 님 식당에 들어감
# 대기 줄 상태 : [None, None, None, None, None]
# 식당 영업 종료!

# %% [markdown]
# ### 3번 문제

# %%
import random

# 전역 변수 선언

SIZE = 20
dataAry = ['콘말차', '삿포로 맥주', '아카페라 벤티 헤이즐넛', '레어치즈푸딩', '척오리지널 메가 사워', '요아정 요거트컵', 
           '페퍼로니피자주먹밥', '널담 슈톨렌', '딸기마시멜로케이크', '버니공쥬 딸기뚱카롱', '고추잡채호빵', '체다 슈크림붕어스낵']
sellAry = [random.choice(dataAry) for _ in range(SIZE)]
changeSellAry = sellAry

# 함수 선언
def run():
    while True:
        sel_menu = set_menu()
        if sel_menu == 1:
            print(f'오늘 판매된 물건(중복O) --> {sellAry}')
            print('------------------------------------')

        elif sel_menu == 2:
            changeSellAry.sort()
            i = 0
            while True:         # 1.첫번째와 두번째 인덱스를 비교를 반복하여
                if i+1 >= len(changeSellAry): # 4. i가 리스트 길이를 넘어가면 break
                    break
                elif changeSellAry[i] != changeSellAry[i+1]:   # 2. 서로 다르면 i를 증가시켜 다음인덱스로 넘어가고,
                    i += 1
                elif changeSellAry[i] == changeSellAry[i+1]:    # 3. 서로 같으면 앞쪽 인덱스(i번)를 리스트에서 삭제한다.
                    del(changeSellAry[i])
            
            print(f'오늘 판매된 물건(중복X) --> {changeSellAry}')
            print('------------------------------------')

        elif sel_menu == 3:
            break
        else:
            print('1, 2, 3 중 입력해주세요')
            print('------------------------------------')

def set_menu():
    str_menu = (f'1. 전체 판매 목록 보기\n'
                '2. 중복된 물품 제외하여 목록 보기\n'
                '3. 프로그램 종료')
    print(str_menu)
    try:
        sel_menu = int(input('메뉴 번호 입력: '))
    except Exception as e:
        sel_menu = 0

    return sel_menu

## 메인코드 ##
if __name__ =='__main__':
    run()
    print('프로그램 종료')
# Out:
# 1. 전체 판매 목록 보기
# 2. 중복된 물품 제외하여 목록 보기
# 3. 프로그램 종료
# 오늘 판매된 물건(중복O) --> ['척오리지널 메가 사워', '체다 슈크림붕어스낵', '척오리지널 메가 사워', '레어치즈푸딩', '삿포로 맥주', '버니공쥬 딸기뚱카롱', '아카페라 벤티 헤이즐넛', '삿포로 맥주', '콘말차', '요아정 요거트컵', '체다 슈크림붕어스낵', '척오리지널 메가 사워', '아카페라 벤티 헤이즐넛', '아카페라 벤티 헤이즐넛', '요아정 요거트컵', '널담 슈톨렌', '아카페라 벤티 헤이즐넛', '딸기마시멜로케이크', '척오리지널 메가 사워', '페퍼로니피자주먹밥']
# ------------------------------------
# 1. 전체 판매 목록 보기
# 2. 중복된 물품 제외하여 목록 보기
# 3. 프로그램 종료
# 오늘 판매된 물건(중복X) --> ['널담 슈톨렌', '딸기마시멜로케이크', '레어치즈푸딩', '버니공쥬 딸기뚱카롱', '삿포로 맥주', '아카페라 벤티 헤이즐넛', '요아정 요거트컵', '척오리지널 메가 사워', '체다 슈크림붕어스낵', '콘말차', '페퍼로니피자주먹밥']
# ------------------------------------
# 1. 전체 판매 목록 보기
# 2. 중복된 물품 제외하여 목록 보기
# 3. 프로그램 종료
# 오늘 판매된 물건(중복X) --> ['널담 슈톨렌', '딸기마시멜로케이크', '레어치즈푸딩', '버니공쥬 딸기뚱카롱', '삿포로 맥주', '아카페라 벤티 헤이즐넛', '요아정 요거트컵', '척오리지널 메가 사워', '체다 슈크림붕어스낵', '콘말차', '페퍼로니피자주먹밥']
# ------------------------------------
# 1. 전체 판매 목록 보기
# 2. 중복된 물품 제외하여 목록 보기
# 3. 프로그램 종료
# 프로그램 종료

# %% [markdown]
# ### 4번 문제

# %%
import random


# 전역변수 선언
dataAry = [random.randint(0,100000) for _ in range(100000)]     # 랜덤함수사용하여 1 ~ 100,000사이 숫자 100,000개 뽑기
findData = random.choice(dataAry)                               # 랜덤함수 사용하여 찾을 데이터 하나 찾기
count = 0
# 함수선언
def binSearch(ary, fData, count):
    pos = -1
    start = 0
    end = len(ary) -1

    while (start <= end):
        mid = (start + end) // 2
        if fData == ary[mid]:
            return mid ,count
        elif fData > ary[mid]:
            start = mid + 1
        else:
            end = mid -1
        count += 1
    return pos

## 메인코드
dataAry.sort()
print(f'배열 일부 --> [{dataAry[0], dataAry[1], dataAry[2], dataAry[3], dataAry[4]}] ~~~~ [{dataAry[-5], dataAry[-4], dataAry[-3], dataAry[-2], dataAry[-1]}]')
postion = binSearch(dataAry, findData, count)
if postion == -1:
    print(f'{findData} (이)가 없네요.')
else:
    print(f'{findData}(은)는 {postion[0]}위치에 있음')  # position의 0번인덱스(mid)
    print(f'{postion[1]}회 검색함') # position의 1번인덱스(count)
# Out:
# 배열 일부 --> [(0, 1, 2, 4, 7)] ~~~~ [(99994, 99994, 99996, 99997, 100000)]
# 9200(은)는 9254위치에 있음
# 14회 검색함
